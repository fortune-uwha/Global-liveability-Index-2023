# %% [markdown]
# <a href="https://colab.research.google.com/github/fortune-uwha/Global-liveability-Index-2023/blob/main/THE_GLOBAL_LIVEABILITY_INDEX_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from io import StringIO

# %%
# text data
data = """City Location Rank Index Stability Healthcare Culture Education Infrastructure
Vienna Austria 1 98.4 100.0 100.0 93.5 100.0 100.0
Copenhagen Denmark 2 98.0 100.0 95.8 95.4 100.0 100.0
Melbourne Australia 3 97.7 95.0 100.0 95.8 100.0 100.0
Sydney Australia 4 97.4 95.0 100.0 94.4 100.0 100.0
Vancouver Canada 5 97.3 95.0 100.0 97.2 100.0 96.4
Zurich Switzerland 6 97.1 95.0 100.0 96.3 100.0 96.4
Calgary Canada 7 96.8 100.0 100.0 87.3 100.0 100.0
Geneva Switzerland 7 96.8 95.0 100.0 94.9 100.0 96.4
Toronto Canada 9 96.5 100.0 100.0 94.4 100.0 89.3
Osaka Japan 10 96.0 100.0 100.0 86.8 100.0 96.4
Auckland New Zealand 10 96.0 95.0 95.8 97.9 100."""

# %%
# Convert the text data to a DataFrame
df = pd.read_csv(StringIO(data), sep='\s+', header=0, engine='python')
df
# Out:
#           City     Location     Rank  Index  Stability  Healthcare  Culture  \
# 0       Vienna      Austria        1   98.4      100.0       100.0     93.5
# 1   Copenhagen      Denmark        2   98.0      100.0        95.8     95.4
# 2    Melbourne    Australia        3   97.7       95.0       100.0     95.8
# 3       Sydney    Australia        4   97.4       95.0       100.0     94.4
# 4    Vancouver       Canada        5   97.3       95.0       100.0     97.2
# 5       Zurich  Switzerland        6   97.1       95.0       100.0     96.3
# 6      Calgary       Canada        7   96.8      100.0       100.0     87.3
# 7       Geneva  Switzerland        7   96.8       95.0       100.0     94.9
# 8      Toronto       Canada        9   96.5      100.0       100.0     94.4
# 9        Osaka        Japan       10   96.0      100.0       100.0     86.8
# 10    Auckland          New  Zealand   10.0       96.0        95.0     95.8
#
#     Education  Infrastructure
# ...

# %%
# Rename columns
df.columns = ['City', 'Location', 'Rank', 'Index', 'Stability', 'Healthcare', 'Culture_Environment', 'Education', 'Infrastructure']

# Display the DataFrame
# Out:
#       City    Location    Rank  Index  Stability  Healthcare  Culture_Environment  Education  Infrastructure
#     Vienna     Austria       1   98.4      100.0       100.0                 93.5      100.0           100.0
# Copenhagen     Denmark       2   98.0      100.0        95.8                 95.4      100.0           100.0
#  Melbourne   Australia       3   97.7       95.0       100.0                 95.8      100.0           100.0
#     Sydney   Australia       4   97.4       95.0       100.0                 94.4      100.0           100.0
#  Vancouver      Canada       5   97.3       95.0       100.0                 97.2      100.0            96.4
#     Zurich Switzerland       6   97.1       95.0       100.0                 96.3      100.0            96.4
#    Calgary      Canada       7   96.8      100.0       100.0                 87.3      100.0           100.0
#     Geneva Switzerland       7   96.8       95.0       100.0                 94.9      100.0            96.4
# ...

# %% [markdown]
# **Method 2: Extract from pdf**

# %%
#pip install tabula-py

# %%
import tabula

# %%
# Using tabula to extract tables from the PDF
tables = tabula.read_pdf('/content/Jun-Global-Liveability-Index-2023.pdf', pages='all')

# %%
top_cities = tables[0]
top_cities.drop(0, inplace=True)
top_cities.reset_index(drop=True, inplace=True)

# %%
top_cities
# Out:
#           City     Location  Rank  Index  Stability  Healthcare Unnamed: 0  \
# 0       Vienna      Austria   1.0   98.4      100.0       100.0       93.5
# 1   Copenhagen      Denmark   2.0   98.0      100.0        95.8       95.4
# 2    Melbourne    Australia   3.0   97.7       95.0       100.0       95.8
# 3       Sydney    Australia   4.0   97.4       95.0       100.0       94.4
# 4    Vancouver       Canada   5.0   97.3       95.0       100.0       97.2
# 5       Zurich  Switzerland   6.0   97.1       95.0       100.0       96.3
# 6      Calgary       Canada   7.0   96.8      100.0       100.0       87.3
# 7       Geneva  Switzerland   7.0   96.8       95.0       100.0       94.9
# 8      Toronto       Canada   9.0   96.5      100.0       100.0       94.4
# 9        Osaka        Japan  10.0   96.0      100.0       100.0       86.8
# 10    Auckland  New Zealand  10.0   96.0       95.0        95.8       97.9
#
#     Education  Infrastructure
# 0       100.0           100.0
# ...

# %%
top_cities.rename(columns={'Unnamed: 0': 'Culture_Environment'}, inplace=True)

# %%
top_cities
# Out:
#           City     Location  Rank  Index  Stability  Healthcare  \
# 0       Vienna      Austria   1.0   98.4      100.0       100.0
# 1   Copenhagen      Denmark   2.0   98.0      100.0        95.8
# 2    Melbourne    Australia   3.0   97.7       95.0       100.0
# 3       Sydney    Australia   4.0   97.4       95.0       100.0
# 4    Vancouver       Canada   5.0   97.3       95.0       100.0
# 5       Zurich  Switzerland   6.0   97.1       95.0       100.0
# 6      Calgary       Canada   7.0   96.8      100.0       100.0
# 7       Geneva  Switzerland   7.0   96.8       95.0       100.0
# 8      Toronto       Canada   9.0   96.5      100.0       100.0
# 9        Osaka        Japan  10.0   96.0      100.0       100.0
# 10    Auckland  New Zealand  10.0   96.0       95.0        95.8
#
#    Culture_Environment  Education  Infrastructure
# 0                 93.5      100.0           100.0
# 1                 95.4      100.0           100.0
# ...

# %%
bottom_cities = tables[1]

# %%
bottom_cities.drop(0, inplace=True)

# %%
bottom_cities.rename(columns={'Unnamed: 0': 'Culture_Environment'}, inplace=True)

# %%
bottom_cities
# Out:
#             City          Location   Rank  Index  Stability  Healthcare  \
# 1         Douala          Cameroon  164.0   46.4       60.0        29.2
# 2           Kyiv           Ukraine  165.0   44.0       40.0        41.7
# 3         Harare          Zimbabwe  166.0   43.8       40.0        29.2
# 4          Dhaka        Bangladesh  166.0   43.8       50.0        41.7
# 5   Port Moresby  Papua New Guinea  168.0   43.4       30.0        41.7
# 6        Karachi          Pakistan  169.0   42.5       20.0        50.0
# 7          Lagos           Nigeria  170.0   42.2       25.0        37.5
# 8        Algiers           Algeria  171.0   42.0       35.0        50.0
# 9        Tripoli             Libya  172.0   40.1       30.0        45.8
# 10      Damascus             Syria  173.0   30.7       20.0        29.2
#
#    Culture_Environment  Education  Infrastructure
# 1                 51.2       41.7            42.9
# 2                 54.2       75.0            23.2
# ...

# %%
top_cities.to_csv('top_cities.csv', index=False)

# %%
bottom_cities.to_csv('bottom_cities.csv', index=False)
